# %%
import numpy as np  
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_excel("../data/vigitel 2019 com colunas traduzidas.xls", skiprows=[0])
df
# Out:
#         Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  idade em anos  sexo  \
# 0        311666031          29        2019          27             88     1
# 1        318136030           4        2019          27             65     1
# 2       1321836026           6        2019          10             68     1
# 3       2323676021          16        2019          10             79     1
# 4       2323716024          22        2019          10             70     1
# ...            ...         ...         ...         ...            ...   ...
# 52438  94312585036           4        2019          17             70     2
# 52439  98318694029           1        2019           7             87     2
# 52440  18315885032          25        2019          17             86     2
# 52441  49311605030           3        2019          17             75     2
# 52442  74315694027          13        2019           7             75     2
#
# ...

# %%
## Perc of value missing by column
pm = df.isna().sum() * 100 / len(df)
md = pd.DataFrame({'column name': df.columns, 'perc': pm})
## Create file
md.to_csv('data_missing.csv')
